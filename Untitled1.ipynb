# %% [markdown]
# # 시각화

# %%
# 한글 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab 경우 Reuntime > Restart session 필요
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Font directories:
# 	/root/.local/share/fonts
# 	/usr/local/share/fonts
# 	/usr/share/fonts
# 	/root/.fonts
# 	/usr/share/fonts/truetype
# 	/usr/share/fonts/truetype/dejavu
# 	/usr/share/fonts/truetype/nanum
# /root/.local/share/fonts: skipping, no such directory
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 2 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 22 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/dejavu: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 관광여행횟수_성별_연령_월별(2020-2022) = gender_age_month(2020-2022)

# %% [markdown]
# ### 1. 년도별 전체(소계) 비교 - 2020, 2021, 2022년도 합계
# ### 2. 년도별 & 월별 비교
# ### 3. 년도별 & 남여 비교
# ### 4. 년도별 & 나이대별 비교

# %%
import numpy as np
import pandas as pd
import pymongo
client=pymongo.MongoClient("192.168.10.240",27017)
db= client['AI_LKJ']
collection=db['gender_age_month(2020-2022)']
data = collection.find()
df_gender_age_month = pd.DataFrame(data)
df_gender_age_month
# Out:
#                           _id classification  values  year month  \
# 0    662616c8db3227b4f2b2649c             전체      소계  2020    1월
# 1    662616c8db3227b4f2b2649d             전체      소계  2020    2월
# 2    662616c8db3227b4f2b2649e             전체      소계  2020    3월
# 3    662616c8db3227b4f2b2649f             전체      소계  2020    4월
# 4    662616c8db3227b4f2b264a0             전체      소계  2020    5월
# ..                        ...            ...     ...   ...   ...
# 355  662616c8db3227b4f2b265ff             연령  70대 이상  2022    8월
# 356  662616c8db3227b4f2b26600             연령  70대 이상  2022    9월
# 357  662616c8db3227b4f2b26601             연령  70대 이상  2022   10월
# 358  662616c8db3227b4f2b26602             연령  70대 이상  2022   11월
# 359  662616c8db3227b4f2b26603             연령  70대 이상  2022   12월
#
#      visitor_counts
# 0             18037
# 1             11381
# 2              9131
# 3             12443
# 4             15824
# ..              ...
# 355            1008
# 356            1427
# 357            1320
# 358            1278
# 359            1191
#
# [360 rows x 6 columns]

# %%
# 결측치와 이상치 확인     -> 없음 확인
df_gender_age_month.isnull().sum()
# Out:
# _id               0
# classification    0
# values            0
# year              0
# month             0
# visitor_counts    0
# dtype: int64

# %%
# 전체적인 컬럼 확인
df_gender_age_month.columns
# Out:
# Index(['_id', 'classification', 'values', 'year', 'month', 'visitor_counts'], dtype='object')

# %%
df_gender_age_month_2020 = df_gender_age_month[df_gender_age_month['classification'] == '전체'].sort_values('visitor_counts', ascending=False)
df_gender_age_month_2020
# Out:
#                          _id classification values  year month  visitor_counts
# 31  662616c8db3227b4f2b264bb             전체     소계  2022    8월           23383
# 33  662616c8db3227b4f2b264bd             전체     소계  2022   10월           22229
# 30  662616c8db3227b4f2b264ba             전체     소계  2022    7월           21865
# 34  662616c8db3227b4f2b264be             전체     소계  2022   11월           21661
# 28  662616c8db3227b4f2b264b8             전체     소계  2022    5월           21469
# 32  662616c8db3227b4f2b264bc             전체     소계  2022    9월           20921
# 29  662616c8db3227b4f2b264b9             전체     소계  2022    6월           20439
# 35  662616c8db3227b4f2b264bf             전체     소계  2022   12월           20412
# 27  662616c8db3227b4f2b264b7             전체     소계  2022    4월           20190
# 16  662616c8db3227b4f2b264ac             전체     소계  2021    5월           19206
# 19  662616c8db3227b4f2b264af             전체     소계  2021    8월           19001
# 21  662616c8db3227b4f2b264b1             전체     소계  2021   10월           18554
# 6   662616c8db3227b4f2b264a2             전체     소계  2020    7월           18330
# 0   662616c8db3227b4f2b2649c             전체     소계  2020    1월           18037
# 18  662616c8db3227b4f2b264ae             전체     소계  2021    7월           17821
# 26  662616c8db3227b4f2b264b6             전체     소계  2022    3월           17356
# 7   662616c8db3227b4f2b264a3             전체     소계  2020    8월           17314
# 23  662616c8db3227b4f2b264b3             전체     소계  2021   12월           17133
# 22  662616c8db3227b4f2b264b2             전체     소계  2021   11월           16853
# 17  662616c8db3227b4f2b264ad             전체     소계  2021    6월           16646
# 15  662616c8db3227b4f2b264ab             전체     소계  2021    4월           16601
# 20  662616c8db3227b4f2b264b0             전체     소계  2021    9월           16514
# 5   662616c8db3227b4f2b264a1             전체     소계  2020    6월           16443
# 24  662616c8db3227b4f2b264b4             전체     소계  2022    1월           16349
# 4   662616c8db3227b4f2b264a0             전체     소계  2020    5월           15824
# 25  662616c8db3227b4f2b264b5             전체     소계  2022    2월           15414
# 14  662616c8db3227b4f2b264aa             전체     소계  2021    3월           14630
# 8   662616c8db3227b4f2b264a4             전체     소계  2020    9월           13496
# 12  662616c8db3227b4f2b264a8             전체     소계  2021    1월           13097
# 9   662616c8db3227b4f2b264a5             전체     소계  2020   10월           12970
# 10  662616c8db3227b4f2b264a6             전체     소계  2020   11월           12795
# 13  662616c8db3227b4f2b264a9             전체     소계  2021    2월           12745
# 11  662616c8db3227b4f2b264a7             전체     소계  2020   12월           12478
# 3   662616c8db3227b4f2b2649f             전체     소계  2020    4월           12443
# 1   662616c8db3227b4f2b2649d             전체     소계  2020    2월           11381
# 2   662616c8db3227b4f2b2649e             전체     소계  2020    3월            9131
