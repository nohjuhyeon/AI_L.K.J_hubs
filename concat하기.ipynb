# %% [markdown]
# ## 관광객 정보

# %%
import pandas as pd
GW_consume_2020 = pd.read_csv('강원_2020_관광소비_내국인.csv', encoding='euc-kr')
GW_consume_2020['지역구분'] = "강원"
GW_consume_transition_2020 = pd.read_csv('강원_2020_관광소비_추이_내국인.csv', encoding='euc-kr')
GW_consume_transition_2020['지역구분'] = "강원"
GW_attraction_2020 = pd.read_csv('강원_2020_내국인_관심_관광지.csv', encoding='euc-kr')
GW_attraction_2020['지역구분'] = "강원"
GW_accompany_2020 = pd.read_csv('강원_2020_동반유형_언급량.csv', encoding='euc-kr')
GW_accompany_2020['지역구분'] = "강원"
GW_concept_2020 = pd.read_csv('강원_2020_목적지_유형별_검색량.csv', encoding='euc-kr')
GW_concept_2020['지역구분'] = "강원"
GW_trend_2020 = pd.read_csv('강원_2020_여행유형_트렌드_언급량.csv', encoding='euc-kr')
GW_trend_2020['지역구분'] = "강원"
GW_consume_transition_entire_2020 = pd.read_csv('강원_2020_전국_대비_관광소비_추이_내국인.csv', encoding='euc-kr')
GW_consume_transition_entire_2020['지역구분'] = "강원"
GW_consume_transition_entire_2020
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 GW_consume_2020 = pd.read_csv('강원_2020_관광소비_내국인.csv', encoding='euc-kr')
#       3 GW_consume_2020['지역구분'] = "강원"
# ----> 4 GW_consume_transition_2020 = pd.read_csv('강원_2020_관광소비_추이_내국인.csv', encoding='euc-kr')
#       5 GW_consume_transition_2020['지역구분'] = "강원"
#       6 GW_attraction_2020 = pd.read_csv('강원_2020_내국인_관심_관광지.csv', encoding='euc-kr')
#
# ...

# %%
BS_consume_2020 = pd.read_csv('부산_2020_관광소비_내국인.csv', encoding='euc-kr')
BS_consume_2020['지역구분'] = "부산"
BS_consume_transition_2020 = pd.read_csv('부산_2020_관광소비_추이_내국인.csv', encoding='euc-kr')
BS_consume_transition_2020['지역구분'] = "부산"
BS_attraction_2020 = pd.read_csv('부산_2020_내국인_관심_관광지.csv', encoding='euc-kr')
BS_attraction_2020['지역구분'] = "부산"
BS_accompany_2020 = pd.read_csv('부산_2020_동반유형_언급량.csv', encoding='euc-kr')
BS_accompany_2020['지역구분'] = "부산"
BS_concept_2020 = pd.read_csv('부산_2020_목적지_유형별_검색량.csv', encoding='euc-kr')
BS_concept_2020['지역구분'] = "부산"
BS_trend_2020 = pd.read_csv('부산_2020_여행유형_트렌드_언급량.csv', encoding='euc-kr')
BS_trend_2020['지역구분'] = "부산"
BS_consume_transition_entire_2020 = pd.read_csv('부산_2020_전국_대비_관광소비_추이_내국인.csv', encoding='euc-kr')
BS_consume_transition_entire_2020['지역구분'] = "부산"
BS_consume_transition_entire_2020
# Out:
#       기준연월    지역명  관광소비액(백만원)  전국 관광소비액(백만원)  전국 대비 관광소비율 지역구분
# 0   202301  부산광역시    258888.0      3193641.0          8.1   부산
# 1   202302  부산광역시    243923.0      3112274.0          7.8   부산
# 2   202303  부산광역시    261158.0      3478043.0          7.5   부산
# 3   202304  부산광역시    267174.0      3619532.0          7.4   부산
# 4   202305  부산광역시    274612.0      3803919.0          7.2   부산
# 5   202306  부산광역시    262734.0      3569349.0          7.4   부산
# 6   202307  부산광역시    268419.0      3589248.0          7.5   부산
# 7   202308  부산광역시    268179.0      3506755.0          7.6   부산
# 8   202309  부산광역시    261700.0      3456150.0          7.6   부산
# 9   202310  부산광역시    278167.0      3672830.0          7.6   부산
# 10  202311  부산광역시    258185.0      3352999.0          7.7   부산
# 11  202312  부산광역시    292906.0      3565655.0          8.2   부산

# %%
SU_consume_2020 = pd.read_csv('서울_2020_관광소비_내국인.csv', encoding='euc-kr')
SU_consume_2020['지역구분'] = "서울"
SU_consume_transition_2020 = pd.read_csv('서울_2020_관광소비_추이_내국인.csv', encoding='euc-kr')
SU_consume_transition_2020['지역구분'] = "서울"
SU_attraction_2020 = pd.read_csv('서울_2020_내국인_관심_관광지.csv', encoding='euc-kr')
SU_attraction_2020['지역구분'] = "서울"
SU_accompany_2020 = pd.read_csv('서울_2020_동반유형_언급량.csv', encoding='euc-kr')
SU_accompany_2020['지역구분'] = "서울"
SU_concept_2020 = pd.read_csv('서울_2020_목적지_유형별_검색량.csv', encoding='euc-kr')
SU_concept_2020['지역구분'] = "서울"
SU_trend_2020 = pd.read_csv('서울_2020_여행유형_트렌드_언급량.csv', encoding='euc-kr')
SU_trend_2020['지역구분'] = "서울"
SU_consume_transition_entire_2020 = pd.read_csv('서울_2020_전국_대비_관광소비_추이_내국인.csv', encoding='euc-kr')
SU_consume_transition_entire_2020['지역구분'] = "서울"
SU_consume_transition_entire_2020
# Out:
#       기준연월    지역명  관광소비액(백만원)  전국 관광소비액(백만원)  전국 대비 관광소비율 지역구분
# 0   202301  서울특별시    989276.0      3193641.0         31.0   서울
# 1   202302  서울특별시    972234.0      3112274.0         31.2   서울
# 2   202303  서울특별시   1061652.0      3478043.0         30.5   서울
# 3   202304  서울특별시   1053476.0      3619532.0         29.1   서울
# 4   202305  서울특별시   1116071.0      3803919.0         29.3   서울
# 5   202306  서울특별시   1061383.0      3569349.0         29.7   서울
# 6   202307  서울특별시   1070818.0      3589248.0         29.8   서울
# 7   202308  서울특별시   1006149.0      3506755.0         28.7   서울
# 8   202309  서울특별시   1001844.0      3456150.0         29.0   서울
# 9   202310  서울특별시   1032694.0      3672830.0         28.1   서울
# 10  202311  서울특별시   1007137.0      3352999.0         30.0   서울
# 11  202312  서울특별시   1127462.0      3565655.0         31.6   서울

# %%
JJ_consume_2020 = pd.read_csv('제주_2020_관광소비_내국인.csv', encoding='euc-kr')
JJ_consume_2020['지역구분'] = "제주"
JJ_consume_transition_2020 = pd.read_csv('제주_2020_관광소비_추이_내국인.csv', encoding='euc-kr')
JJ_consume_transition_2020['지역구분'] = "제주"
JJ_attraction_2020 = pd.read_csv('제주_2020_내국인_관심_관광지.csv', encoding='euc-kr')
JJ_attraction_2020['지역구분'] = "제주"
JJ_accompany_2020 = pd.read_csv('제주_2020_동반유형_언급량.csv', encoding='euc-kr')
JJ_accompany_2020['지역구분'] = "제주"
JJ_concept_2020 = pd.read_csv('제주_2020_목적지_유형별_검색량.csv', encoding='euc-kr')
JJ_concept_2020['지역구분'] = "제주"
JJ_trend_2020 = pd.read_csv('제주_2020_여행유형_트렌드_언급량.csv', encoding='euc-kr')
JJ_trend_2020['지역구분'] = "제주"
JJ_consume_transition_entire_2020 = pd.read_csv('제주_2020_전국_대비_관광소비_추이_내국인.csv', encoding='euc-kr')
JJ_consume_transition_entire_2020['지역구분'] = "제주"
JJ_consume_transition_entire_2020
# Out:
#       기준연월      지역명  관광소비액(백만원)  전국 관광소비액(백만원)  전국 대비 관광소비율 지역구분
# 0   202301  제주특별자치도     83872.0      3193641.0          2.6   제주
# 1   202302  제주특별자치도     84610.0      3112274.0          2.7   제주
# 2   202303  제주특별자치도     86661.0      3478043.0          2.5   제주
# 3   202304  제주특별자치도     95733.0      3619532.0          2.6   제주
# 4   202305  제주특별자치도    100666.0      3803919.0          2.6   제주
# 5   202306  제주특별자치도     96518.0      3569349.0          2.7   제주
# 6   202307  제주특별자치도     91259.0      3589248.0          2.5   제주
# 7   202308  제주특별자치도    102788.0      3506755.0          2.9   제주
# 8   202309  제주특별자치도     81507.0      3456150.0          2.4   제주
# 9   202310  제주특별자치도     92968.0      3672830.0          2.5   제주
# 10  202311  제주특별자치도     78435.0      3352999.0          2.3   제주
# 11  202312  제주특별자치도     74784.0      3565655.0          2.1   제주

# %%
IC_consume_2020 = pd.read_csv('인천_2020_관광소비_내국인.csv', encoding='euc-kr')
IC_consume_2020['지역구분'] = "인천"
IC_consume_transition_2020 = pd.read_csv('인천_2020_관광소비_추이_내국인.csv', encoding='euc-kr')
IC_consume_transition_2020
IC_consume_transition_2020['지역구분'] = "인천"
IC_attraction_2020 = pd.read_csv('인천_2020_내국인_관심_관광지.csv', encoding='euc-kr')
IC_attraction_2020
IC_attraction_2020['지역구분'] = "인천"
IC_accompany_2020 = pd.read_csv('인천_2020_동반유형_언급량.csv', encoding='euc-kr')
IC_accompany_2020
IC_accompany_2020['지역구분'] = "인천"
IC_concept_2020 = pd.read_csv('인천_2020_목적지_유형별_검색량.csv', encoding='euc-kr')
IC_concept_2020
IC_concept_2020['지역구분'] = "인천"
IC_trend_2020 = pd.read_csv('인천_2020_여행유형_트렌드_언급량.csv', encoding='euc-kr')
IC_trend_2020
IC_trend_2020['지역구분'] = "인천"
IC_consume_transition_entire_2020 = pd.read_csv('인천_2020_전국_대비_관광소비_추이_내국인.csv', encoding='euc-kr')
IC_consume_transition_entire_2020['지역구분'] = "인천"
IC_consume_transition_entire_2020
# Out:
#       기준연월    지역명  관광소비액(백만원)  전국 관광소비액(백만원)  전국 대비 관광소비율 지역구분
# 0   202301  인천광역시    156104.0      3193641.0          4.9   인천
# 1   202302  인천광역시    148695.0      3112274.0          4.8   인천
# 2   202303  인천광역시    164691.0      3478043.0          4.7   인천
# 3   202304  인천광역시    172693.0      3619532.0          4.8   인천
# 4   202305  인천광역시    180669.0      3803919.0          4.7   인천
# 5   202306  인천광역시    172816.0      3569349.0          4.8   인천
# 6   202307  인천광역시    174388.0      3589248.0          4.9   인천
# 7   202308  인천광역시    167264.0      3506755.0          4.8   인천
# 8   202309  인천광역시    168310.0      3456150.0          4.9   인천
# 9   202310  인천광역시    176363.0      3672830.0          4.8   인천
# 10  202311  인천광역시    157007.0      3352999.0          4.7   인천
# 11  202312  인천광역시    174935.0      3565655.0          4.9   인천

# %%
consume_transition_entire_2020=pd.concat(objs=[IC_consume_transition_entire_2020,BS_consume_transition_entire_2020,SU_consume_transition_entire_2020,JJ_consume_transition_entire_2020,GW_consume_transition_entire_2020])
consume_transition_entire_2020
# Out:
#       기준연월      지역명  관광소비액(백만원)  전국 관광소비액(백만원)  전국 대비 관광소비율 지역구분
# 0   202301    인천광역시    156104.0      3193641.0          4.9   인천
# 1   202302    인천광역시    148695.0      3112274.0          4.8   인천
# 2   202303    인천광역시    164691.0      3478043.0          4.7   인천
# 3   202304    인천광역시    172693.0      3619532.0          4.8   인천
# 4   202305    인천광역시    180669.0      3803919.0          4.7   인천
# 5   202306    인천광역시    172816.0      3569349.0          4.8   인천
# 6   202307    인천광역시    174388.0      3589248.0          4.9   인천
# 7   202308    인천광역시    167264.0      3506755.0          4.8   인천
# 8   202309    인천광역시    168310.0      3456150.0          4.9   인천
# 9   202310    인천광역시    176363.0      3672830.0          4.8   인천
# 10  202311    인천광역시    157007.0      3352999.0          4.7   인천
# 11  202312    인천광역시    174935.0      3565655.0          4.9   인천
# 0   202301    부산광역시    258888.0      3193641.0          8.1   부산
# ...

# %%
trend_2020=pd.concat(objs=[IC_trend_2020,BS_trend_2020,SU_trend_2020,JJ_trend_2020,GW_trend_2020])
trend_2020
# Out:
#       기준연월 여행유형/트렌드명   언급건수 지역구분
# 0   202310     휴식/힐링  25282   인천
# 1   202308     휴식/힐링  23383   인천
# 2   202306     휴식/힐링  22363   인천
# 3   202309     휴식/힐링  21743   인천
# 4   202305     휴식/힐링  21319   인천
# ..     ...       ...    ...  ...
# 55  202310        미식   2699   강원
# 56  202304        미식   2699   강원
# 57  202311        미식   2614   강원
# 58  202302        체험   2555   강원
# 59  202312        미식   2512   강원
#
# [300 rows x 4 columns]

# %%
concept_2020 = pd.concat(objs=[IC_concept_2020,BS_concept_2020,SU_concept_2020,JJ_concept_2020,GW_concept_2020])
concept_2020
# Out:
#        기준연월 목적지 유형  목적지 검색량 지역구분
# 0    202303     전체  2518330   인천
# 1    202304     전체  2458340   인천
# 2    202306     전체  2599826   인천
# 3    202307     전체  2640547   인천
# 4    202309     전체  3066439   인천
# ..      ...    ...      ...  ...
# 115  202312   문화관광   230390   강원
# 116  202312   역사관광    56014   강원
# 117  202312   자연관광   217036   강원
# 118  202312   체험관광    16478   강원
# 119  202312  레저스포츠   128227   강원
#
# [600 rows x 4 columns]

# %%
accompany_2020 = pd.concat(objs=[IC_accompany_2020,BS_accompany_2020,SU_accompany_2020,JJ_accompany_2020,GW_accompany_2020])
accompany_2020
# Out:
#        기준연월 동반유형명    언급건수 지역구분
# 0    202308  기타가족  115629   인천
# 1    202312  기타가족  110697   인천
# 2    202307  기타가족  109663   인천
# 3    202310  기타가족  108737   인천
# 4    202305  기타가족  108036   인천
# ..      ...   ...     ...  ...
# 103  202310    학생    8098   강원
# 104  202303    학생    8051   강원
# 105  202311    학생    8051   강원
# 106  202305    학생    7678   강원
# 107  202304    학생    7211   강원
#
# [540 rows x 4 columns]

# %%
attraction_2020 = pd.concat(objs=[IC_attraction_2020,BS_attraction_2020,SU_attraction_2020,JJ_attraction_2020,GW_attraction_2020])
attraction_2020
# Out:
#    시군구명      시도명              관광지명  \
# 0   강화군    인천광역시        석모도 미네랄 온천
# 1   옹진군    인천광역시          선재바다낚시공원
# 2   강화군    인천광역시              조양방직
# 3    중구    인천광역시               무의도
# 4   강화군    인천광역시            강화 전등사
# ..  ...      ...               ...
# 95  속초시  강원특별자치도  속초관광수산시장(구 중앙시장)
# 96  정선군  강원특별자치도       하이원 하늘길 트레킹
# 97  강릉시  강원특별자치도           강릉 월화거리
# 98  강릉시  강원특별자치도             정동진해변
# 99  고성군  강원특별자치도    미시령옛길 울산바위 은하수
#
#                                            Unnamed: 3   KTO카테고리대분류명  \
# 0   https://korean.visitkorea.or.kr/detail/ms_deta...  인문(문화/예술/역사)
# 1   https://korean.visitkorea.or.kr/detail/ms_deta...           레포츠
# 2   https://korean.visitkorea.or.kr/detail/ms_deta...            음식
# 3   https://korean.visitkorea.or.kr/detail/ms_deta...            자연
# 4   https://korean.visitkorea.or.kr/detail/ms_deta...  인문(문화/예술/역사)
# ..                                                ...           ...
# ...

# %%
consume_2020 = pd.concat(objs=[IC_consume_2020,BS_consume_2020,SU_consume_2020,JJ_consume_2020,GW_consume_2020])
consume_2020
# Out:
#    업종대분류명  업종중분류명   중분류 소비액(천원) 지역구분
# 0     쇼핑업     면세점  1.923002e+08   인천
# 1     쇼핑업   관광기념품  1.809399e+06   인천
# 2     쇼핑업  레저용품쇼핑  1.117589e+08   인천
# 3     쇼핑업   대형쇼핑몰  4.024763e+08   인천
# 4     숙박업      호텔  3.535387e+07   인천
# ..    ...     ...           ...  ...
# 14    여행업     여행업  2.674231e+06   강원
# 15    운송업    수상운송  5.331678e+05   강원
# 16    운송업     렌터카  2.956524e+05   강원
# 17    운송업    항공운송  2.000000e+02   강원
# 18    운송업    육상운송  4.024705e+05   강원
#
# [93 rows x 4 columns]

# %%
consume_transition_2020 = pd.concat(objs=[IC_consume_transition_2020,BS_consume_transition_2020,SU_consume_transition_2020,JJ_consume_transition_2020,GW_consume_transition_2020])
consume_transition_2020
# Out:
#       기준연월 업종대분류명      소비액(천원) 지역구분
# 0   202312     전체  174935427.0   인천
# 1   202301     전체  156103505.0   인천
# 2   202302     전체  148694606.0   인천
# 3   202303     전체  164691002.0   인천
# 4   202304     전체  172693160.0   인천
# ..     ...    ...          ...  ...
# 79  202305    쇼핑업   14914005.0   강원
# 80  202305    운송업     109760.0   강원
# 81  202305    숙박업   14634523.0   강원
# 82  202304    여행업     174354.0   강원
# 83  202304   식음료업   58426095.0   강원
#
# [420 rows x 4 columns]

# %%
consume_2020.to_csv('consume_2020.csv',index=False,encoding='utf-8')

# %%
attraction_2020.to_csv('attraction_2020.csv',index=False,encoding='utf-8')

# %%
accompany_2020.to_csv('accompany_2020.csv',index=False,encoding='utf-8')

# %%
concept_2020.to_csv('concept_2020.csv',index=False,encoding='utf-8')

# %%
trend_2020.to_csv('trend_2020.csv',index=False,encoding='utf-8')

# %%
consume_transition_entire_2020.to_csv('consume_transition_entire_2020.csv',index=False,encoding='utf-8')

# %%
consume_transition_2020.to_csv('consume_transition_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## 일별 관광객 수

# %%
import pandas as pd

# %%
seoul_202001 = pd.read_csv("서울_202001_방문자 수 추이.csv", encoding='euc-kr')
seoul_202002 = pd.read_csv("서울_202002_방문자 수 추이.csv", encoding='euc-kr')
seoul_202003 = pd.read_csv("서울_202003_방문자 수 추이.csv", encoding='euc-kr')
seoul_202004 = pd.read_csv("서울_202004_방문자 수 추이.csv", encoding='euc-kr')
seoul_202005 = pd.read_csv("서울_202005_방문자 수 추이.csv", encoding='euc-kr')
seoul_202006 = pd.read_csv("서울_202006_방문자 수 추이.csv", encoding='euc-kr')
seoul_202007 = pd.read_csv("서울_202007_방문자 수 추이.csv", encoding='euc-kr')
seoul_202008 = pd.read_csv("서울_202008_방문자 수 추이.csv", encoding='euc-kr')
seoul_202009 = pd.read_csv("서울_202009_방문자 수 추이.csv", encoding='euc-kr')
seoul_202010 = pd.read_csv("서울_202010_방문자 수 추이.csv", encoding='euc-kr')
seoul_202011 = pd.read_csv("서울_202011_방문자 수 추이.csv", encoding='euc-kr')
seoul_202012 = pd.read_csv("사을_202012_방문자 수 추이.csv", encoding='euc-kr')
SU_date_visitor_2020 = pd.concat(objs=[seoul_202001,seoul_202002,seoul_202003,seoul_202004,seoul_202005,seoul_202006,seoul_202007,seoul_202008,seoul_202009,seoul_202010,seoul_202011,seoul_202012])
SU_date_visitor_2020["지역구분"] = "서울"
SU_date_visitor_2020
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-b90a0d7755a1> in <cell line: 1>()
# ----> 1 seoul_202301 = pd.read_csv("서울_202301_방문자 수 추이.csv", encoding='euc-kr')
#       2 seoul_202302 = pd.read_csv("서울_202302_방문자 수 추이.csv", encoding='euc-kr')
#       3 seoul_202303 = pd.read_csv("서울_202303_방문자 수 추이.csv", encoding='euc-kr')
#       4 seoul_202304 = pd.read_csv("서울_202304_방문자 수 추이.csv", encoding='euc-kr')
#       5 seoul_202305 = pd.read_csv("서울_202305_방문자 수 추이.csv", encoding='euc-kr')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %%
IC_202001 = pd.read_csv("인천_202001_방문자_수_추이.csv", encoding='euc-kr')
IC_202002 = pd.read_csv("인천_202002_방문자_수_추이.csv", encoding='euc-kr')
IC_202003 = pd.read_csv("인천_202003_방문자_수_추이.csv", encoding='euc-kr')
IC_202004 = pd.read_csv("인천_202004_방문자_수_추이.csv", encoding='euc-kr')
IC_202005 = pd.read_csv("인천_202005_방문자_수_추이.csv", encoding='euc-kr')
IC_202006 = pd.read_csv("인천_202006_방문자_수_추이.csv", encoding='euc-kr')
IC_202007 = pd.read_csv("인천_202007_방문자_수_추이.csv", encoding='euc-kr')
IC_202008 = pd.read_csv("인천_202008_방문자_수_추이.csv", encoding='euc-kr')
IC_202009 = pd.read_csv("인천_202009_방문자_수_추이.csv", encoding='euc-kr')
IC_202010 = pd.read_csv("인천_202010_방문자_수_추이.csv", encoding='euc-kr')
IC_202011 = pd.read_csv("인천_202011_방문자_수_추이.csv", encoding='euc-kr')
IC_202012 = pd.read_csv("인천_202012_방문자_수_추이.csv", encoding='euc-kr')
IC_date_visitor_2020 = pd.concat(objs=[IC_202001,IC_202002,IC_202003,IC_202004,IC_202005,IC_202006,IC_202007,IC_202008,IC_202009,IC_202010,IC_202011,IC_202012])
IC_date_visitor_2020["지역구분"] = "인천"
IC_date_visitor_2020
# Out:
#          기준년월  광역지자체        방문자 구분      방문자 수 지역구분
# 0    20230101  인천광역시     현지인방문자(a)  1201998.0   인천
# 1    20230101  인천광역시     외지인방문자(b)   518648.0   인천
# 2    20230101  인천광역시     외국인방문자(c)     9159.0   인천
# 3    20230102  인천광역시     현지인방문자(a)  1307516.0   인천
# 4    20230102  인천광역시     외지인방문자(b)   314976.0   인천
# ..        ...    ...           ...        ...  ...
# 150  20231227  인천광역시  전체방문자(a+b+c)  1821609.0   인천
# 151  20231228  인천광역시  전체방문자(a+b+c)  1831811.0   인천
# 152  20231229  인천광역시  전체방문자(a+b+c)  1916956.0   인천
# 153  20231230  인천광역시  전체방문자(a+b+c)  1871306.0   인천
# 154  20231231  인천광역시  전체방문자(a+b+c)  1951591.0   인천
#
# [1825 rows x 5 columns]

# %%
GW_202006
# Out:
#          기준년월    광역지자체        방문자 구분      방문자 수
# 0    20230601  강원특별자치도     현지인방문자(a)  1092150.0
# 1    20230601  강원특별자치도     외지인방문자(b)   241724.0
# 2    20230601  강원특별자치도     외국인방문자(c)      992.0
# 3    20230602  강원특별자치도     현지인방문자(a)  1088528.0
# 4    20230602  강원특별자치도     외지인방문자(b)   315539.0
# ..        ...      ...           ...        ...
# 145  20230626  강원특별자치도  전체방문자(a+b+c)  1347524.0
# 146  20230627  강원특별자치도  전체방문자(a+b+c)  1382045.0
# 147  20230628  강원특별자치도  전체방문자(a+b+c)  1392233.0
# 148  20230629  강원특별자치도  전체방문자(a+b+c)  1336840.0
# 149  20230630  강원특별자치도  전체방문자(a+b+c)  1471817.0
#
# [150 rows x 4 columns]

# %%
GW_202001 = pd.read_csv("강원_202001_방문자 수 추이.csv", encoding='euc-kr')
GW_202002 = pd.read_csv("강원_202002_방문자 수 추이.csv", encoding='euc-kr')
GW_202003 = pd.read_csv("강원_202003_방문자 수 추이.csv", encoding='euc-kr')
GW_202004 = pd.read_csv("강원_202004_방문자 수 추이.csv", encoding='euc-kr')
GW_202005 = pd.read_csv("강원_202005_방문자 수 추이.csv", encoding='euc-kr')
GW_202006 = pd.read_csv("강원_202006_방문자 수 추이.csv", encoding='euc-kr')
GW_202007 = pd.read_csv("강원_202007_방문자 수 추이.csv", encoding='euc-kr')
GW_202008 = pd.read_csv("강원_202008_방문자 수 추이.csv", encoding='euc-kr')
GW_202009 = pd.read_csv("강원_202009_방문자 수 추이.csv", encoding='euc-kr')
GW_202010 = pd.read_csv("강원_202010_방문자 수 추이.csv", encoding='euc-kr')
GW_202011 = pd.read_csv("강원_202011_방문자 수 추이.csv", encoding='euc-kr')
GW_202012 = pd.read_csv("강원_202012_방문자 수 추이.csv", encoding='euc-kr')
GW_date_visitor_2020 = pd.concat(objs=[GW_202001,GW_202002,GW_202003,GW_202004,GW_202005,GW_202006,GW_202007,GW_202008,GW_202009,GW_202010,GW_202011,GW_202012])
GW_date_visitor_2020["지역구분"] = "강원"
GW_date_visitor_2020
# Out:
#          기준년월    광역지자체        방문자 구분      방문자 수 지역구분
# 0    20230101  강원특별자치도     현지인방문자(a)   838901.0   강원
# 1    20230101  강원특별자치도     외지인방문자(b)   627358.0   강원
# 2    20230101  강원특별자치도     외국인방문자(c)      798.0   강원
# 3    20230102  강원특별자치도     현지인방문자(a)   927129.0   강원
# 4    20230102  강원특별자치도     외지인방문자(b)   288428.0   강원
# ..        ...      ...           ...        ...  ...
# 150  20231227  강원특별자치도  전체방문자(a+b+c)  1405597.0   강원
# 151  20231228  강원특별자치도  전체방문자(a+b+c)  1422650.0   강원
# 152  20231229  강원특별자치도  전체방문자(a+b+c)  1534357.0   강원
# 153  20231230  강원특별자치도  전체방문자(a+b+c)  1550114.0   강원
# 154  20231231  강원특별자치도  전체방문자(a+b+c)  1598244.0   강원
#
# [1825 rows x 5 columns]

# %%
BS_202001 = pd.read_csv("부산_202001_방문자 수 추이.csv", encoding='euc-kr')
BS_202002 = pd.read_csv("부산_202002_방문자 수 추이.csv", encoding='euc-kr')
BS_202003 = pd.read_csv("부산_202003_방문자 수 추이.csv", encoding='euc-kr')
BS_202004 = pd.read_csv("부산_202004_방문자 수 추이.csv", encoding='euc-kr')
BS_202005 = pd.read_csv("부산_202005_방문자 수 추이.csv", encoding='euc-kr')
BS_202006 = pd.read_csv("부산_202006_방문자 수 추이.csv", encoding='euc-kr')
BS_202007 = pd.read_csv("부산_202007_방문자 수 추이.csv", encoding='euc-kr')
BS_202008 = pd.read_csv("부산_202008_방문자 수 추이.csv", encoding='euc-kr')
BS_202009 = pd.read_csv("부산_202009_방문자 수 추이.csv", encoding='euc-kr')
BS_202010 = pd.read_csv("부산_202010_방문자 수 추이.csv", encoding='euc-kr')
BS_202011 = pd.read_csv("부산_202011_방문자 수 추이.csv", encoding='euc-kr')
BS_202012 = pd.read_csv("부산_202012_방문자 수 추이.csv", encoding='euc-kr')
BS_date_visitor_2020 = pd.concat(objs=[BS_202001,BS_202002,BS_202003,BS_202004,BS_202005,BS_202006,BS_202007,BS_202008,BS_202009,BS_202010,BS_202011,BS_202012])
BS_date_visitor_2020["지역구분"] = "부산"
BS_date_visitor_2020
# Out:
#          기준년월  광역지자체        방문자 구분      방문자 수 지역구분
# 0    20230101  부산광역시     현지인방문자(a)  1410605.0   부산
# 1    20230101  부산광역시     외지인방문자(b)   461450.0   부산
# 2    20230101  부산광역시     외국인방문자(c)      902.0   부산
# 3    20230102  부산광역시     현지인방문자(a)  1550126.0   부산
# 4    20230102  부산광역시     외지인방문자(b)   292380.0   부산
# ..        ...    ...           ...        ...  ...
# 150  20231227  부산광역시  전체방문자(a+b+c)  1971653.0   부산
# 151  20231228  부산광역시  전체방문자(a+b+c)  1988686.0   부산
# 152  20231229  부산광역시  전체방문자(a+b+c)  2069646.0   부산
# 153  20231230  부산광역시  전체방문자(a+b+c)  2096995.0   부산
# 154  20231231  부산광역시  전체방문자(a+b+c)  2075174.0   부산
#
# [1825 rows x 5 columns]

# %%
JJ_202001 = pd.read_csv("제주_202001_방문자_수_추이.csv", encoding='euc-kr')
JJ_202002 = pd.read_csv("제주_202002_방문자_수_추이.csv", encoding='euc-kr')
JJ_202003 = pd.read_csv("제주_202003_방문자_수_추이.csv", encoding='euc-kr')
JJ_202004 = pd.read_csv("제주_202004_방문자_수_추이.csv", encoding='euc-kr')
JJ_202005 = pd.read_csv("제주_202005_방문자_수_추이.csv", encoding='euc-kr')
JJ_202006 = pd.read_csv("제주_202006_방문자_수_추이.csv", encoding='euc-kr')
JJ_202007 = pd.read_csv("제주_202007_방문자_수_추이.csv", encoding='euc-kr')
JJ_202008 = pd.read_csv("제주_202008_방문자_수_추이.csv", encoding='euc-kr')
JJ_202009 = pd.read_csv("제주_202009_방문자_수_추이.csv", encoding='euc-kr')
JJ_202010 = pd.read_csv("제주_202010_방문자_수_추이.csv", encoding='euc-kr')
JJ_202011 = pd.read_csv("제주_202011_방문자_수_추이.csv", encoding='euc-kr')
JJ_202012 = pd.read_csv("제주_202012_방문자_수_추이.csv", encoding='euc-kr')
JJ_date_visitor_2020 = pd.concat(objs=[JJ_202001,JJ_202002,JJ_202003,JJ_202004,JJ_202005,JJ_202006,JJ_202007,JJ_202008,JJ_202009,JJ_202010,JJ_202011,JJ_202012])
JJ_date_visitor_2020["지역구분"] = "제주"
JJ_date_visitor_2020
# Out:
#          기준년월    광역지자체        방문자 구분     방문자 수 지역구분
# 0    20230101  제주특별자치도     현지인방문자(a)  522918.0   제주
# 1    20230101  제주특별자치도     외지인방문자(b)  163026.0   제주
# 2    20230101  제주특별자치도     외국인방문자(c)     223.0   제주
# 3    20230102  제주특별자치도     현지인방문자(a)  549504.0   제주
# 4    20230102  제주특별자치도     외지인방문자(b)  152926.0   제주
# ..        ...      ...           ...       ...  ...
# 150  20231227  제주특별자치도  전체방문자(a+b+c)  755361.0   제주
# 151  20231228  제주특별자치도  전체방문자(a+b+c)  765310.0   제주
# 152  20231229  제주특별자치도  전체방문자(a+b+c)  774699.0   제주
# 153  20231230  제주특별자치도  전체방문자(a+b+c)  763709.0   제주
# 154  20231231  제주특별자치도  전체방문자(a+b+c)  742863.0   제주
#
# [1825 rows x 5 columns]

# %%
date_visitor_2020 = pd.concat(objs=[IC_date_visitor_2020,BS_date_visitor_2020,SU_date_visitor_2020,JJ_date_visitor_2020,GW_date_visitor_2020])

# %%
date_visitor_2020.to_csv('date_visitor_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## festival

# %%
import pandas as pd
GW_festival_2020 = pd.read_csv("AI_LKJ.festival_Gangwon-do.csv").drop('_id', axis=1)
IC_festival_2020 = pd.read_csv("AI_LKJ.festival_Incheon.csv").drop('_id', axis=1)
JJ_festival_2020 = pd.read_csv("AI_LKJ.festival_Jeju.csv").drop('_id', axis=1)
BS_festival_2020 = pd.read_csv("AI_LKJ.festival_busan.csv").drop('_id', axis=1)
SU_festival_2020 = pd.read_csv("AI_LKJ.festival_seoul.csv").drop('_id', axis=1)
SU_festival_2020
# Out:
#      region                  title                     address  \
# 0        서울                 서울장미축제          서울특별시 중랑구 중랑천로 332
# 1        서울            제10회 서울동화축제       서울특별시 광진구 능동로 216(능동)
# 2        서울        강남아트X2023 서울아트쇼        서울특별시 강남구 영동대로 513 등
# 3        서울           2023 관악강감찬축제           서울특별시 관악구 낙성대로 77
# 4        서울  제20회 강북구 3·1독립운동 기념행사    서울특별시 강북구 삼양로173길 107-12
# ...     ...                    ...                         ...
# 1021     서울              꽃지 해넘이 행사                         NaN
# 1022     서울             부산시민의종 타종식  부산광역시 중구 용두산길 37-55(광복동2가)
# 1023     서울                  해맞이축제                         NaN
# 1024     서울             간절곶 해맞이 축제    울산광역시 울주군 서생면 간절곶1길 39-2
# 1025     서울             정서진 해넘이 행사           인천광역시 서구 정서진1로 41
#
#                               date
# 0     일정 : 2023.05.13 ~ 2023.05.28
# 1     일정 : 2023.05.06 ~ 2023.05.07
# 2     일정 : 2023.12.22 ~ 2023.12.26
# 3     일정 : 2023.10.13 ~ 2023.10.15
# ...

# %%
festival_period_2020 = pd.concat(objs=[IC_festival_2020,BS_festival_2020,SU_festival_2020,JJ_festival_2020,GW_festival_2020])

# %%
festival_period_2020.to_csv('festival_period_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## 동반유형 키워드

# %%
import pandas as pd
GW_accompany_keyword_2020 = pd.read_csv("강원_동반유형 키워드.csv", encoding='euc-kr')
GW_accompany_keyword_2020['지역구분'] = "강원"
IC_accompany_keyword_2020 = pd.read_csv("인천_동반유형 키워드.csv", encoding='euc-kr')
IC_accompany_keyword_2020['지역구분'] = "인천"
JJ_accompany_keyword_2020 = pd.read_csv("제주_동반유형 키워드.csv", encoding='euc-kr')
JJ_accompany_keyword_2020['지역구분'] = "제주"
BS_accompany_keyword_2020 = pd.read_csv("부산_동반유형 키워드.csv", encoding='euc-kr')
BS_accompany_keyword_2020['지역구분'] = "부산"
SU_accompany_keyword_2020 = pd.read_csv("서울_동반유형 키워드.csv", encoding='euc-kr')
SU_accompany_keyword_2020['지역구분'] = "서울"
SU_accompany_keyword_2020
# Out:
#       순위    분류 관련 키워드     언급건수 지역구분
# 0      1    친구     친구  2498631   서울
# 1      2  회사동료     직원  1886885   서울
# 2      3  기타가족     가족  1616617   서울
# 3      4    친구    친구들  1154964   서울
# 4      5    싱글     혼자   988531   서울
# ..   ...   ...    ...      ...  ...
# 416  415   배우자    마낫님        2   서울
# 417  415    자녀    첫아가        2   서울
# 418  419   배우자   우리마눌        1   서울
# 419  419   배우자  저희신랑님        1   서울
# 420  419   부모님  예비시아빠        1   서울
#
# [421 rows x 5 columns]

# %%
accompany_keyword_2020 = pd.concat(objs=[IC_accompany_keyword_2020,BS_accompany_keyword_2020,SU_accompany_keyword_2020,JJ_accompany_keyword_2020,GW_accompany_keyword_2020])
accompany_keyword_2020
# Out:
#       순위    분류  관련 키워드    언급건수 지역구분
# 0      1  기타가족      가족  443816   인천
# 1      2    친구      친구  391310   인천
# 2      3  회사동료      직원  369962   인천
# 3      4  기타가족      가정  207431   인천
# 4      5    친구     친구들  192353   인천
# ..   ...   ...     ...     ...  ...
# 400  400   배우자   저희신랑님       1   강원
# 401  400   부모님  예비시어머니       1   강원
# 402  400   배우자   저희집사람       1   강원
# 403  400   부모님  예비시아버님       1   강원
# 404  400   배우자    저희남푠       1   강원
#
# [2044 rows x 5 columns]

# %%
accompany_keyword_2020.to_csv('accompany_keyword_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## 여행유형 키워드

# %%
import pandas as pd
GW_trend_keyword_2020 = pd.read_csv("강원_여행유형_트렌드 키워드.csv", encoding='euc-kr')
GW_trend_keyword_2020['지역구분'] = "강원"
IC_trend_keyword_2020 = pd.read_csv("인천_여행유형_트렌드 키워드.csv", encoding='euc-kr')
IC_trend_keyword_2020['지역구분'] = "인천"
JJ_trend_keyword_2020 = pd.read_csv("제주_여행유형_트렌드 키워드.csv", encoding='euc-kr')
JJ_trend_keyword_2020['지역구분'] = "제주"
BS_trend_keyword_2020 = pd.read_csv("부산_여행유형_트렌드 키워드.csv", encoding='euc-kr')
BS_trend_keyword_2020['지역구분'] = "부산"
SU_trend_keyword_2020 = pd.read_csv("서울_여행유형_트렌드 키워드.csv", encoding='euc-kr')
SU_trend_keyword_2020['지역구분'] = "서울"
SU_trend_keyword_2020
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-21ceba0893b4> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 GW_trend_keyword_2023 = pd.read_csv("강원_여행유형_트렌드 키워드.csv", encoding='euc-kr')
#       3 GW_trend_keyword_2023['지역구분'] = "강원"
#       4 IC_trend_keyword_2023 = pd.read_csv("인천_여행유형_트렌드 키워드.csv", encoding='euc-kr')
#       5 IC_trend_keyword_2023['지역구분'] = "인천"
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# ...

# %%
trend_keyword_2020 = pd.concat(objs=[IC_trend_keyword_2020,BS_trend_keyword_2020,SU_trend_keyword_2020,JJ_trend_keyword_2020,GW_trend_keyword_2020])
trend_keyword_2020
# Out:
#       순위     분류   관련 키워드    언급건수 지역구분
# 0      1  휴식/힐링       힐링  104518   인천
# 1      2  휴식/힐링      나들이   46381   인천
# 2      3    레포츠       캠핑   43371   인천
# 3      4     기타       투어   30552   인천
# 4      5    레포츠       등산   30371   인천
# ..   ...    ...      ...     ...  ...
# 424  420  휴식/힐링      백캉스       1   강원
# 425  420    레포츠  오프로드라이딩       1   강원
# 426  420     체험    현지인체험       1   강원
# 427  420    레포츠     bsac       1   강원
# 428  420     체험  전기자전거체험       1   강원
#
# [2115 rows x 5 columns]

# %%
trend_keyword_2020.to_csv('trend_keyword_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## 월별 방문객

# %%
import pandas as pd
GW_month_visitor_2020 = pd.read_csv("강원_방문자 수(연인원) 추이.csv", encoding='euc-kr')
GW_month_visitor_2020['지역구분'] = "강원"
IC_month_visitor_2020 = pd.read_csv("인천_방문자 수(연인원) 추이.csv", encoding='euc-kr')
IC_month_visitor_2020['지역구분'] = "인천"
JJ_month_visitor_2020 = pd.read_csv("제주_방문자 수(연인원) 추이.csv", encoding='euc-kr')
JJ_month_visitor_2020['지역구분'] = "제주"
BS_month_visitor_2020 = pd.read_csv("부산_방문자 수(연인원) 추이.csv", encoding='euc-kr')
BS_month_visitor_2020['지역구분'] = "부산"
SU_month_visitor_2020 = pd.read_csv("서울_방문자 수(연인원) 추이.csv", encoding='euc-kr')
SU_month_visitor_2020['지역구분'] = "서울"
SU_month_visitor_2020
# Out:
#       기준년월     방문자_수 지역구분
# 0   202301  47255715   서울
# 1   202302  47090565   서울
# 2   202303  54980858   서울
# 3   202304  45025765   서울
# 4   202305  49506461   서울
# 5   202306  47768488   서울
# 6   202307  50292484   서울
# 7   202308  49277340   서울
# 8   202309  51928425   서울
# 9   202310  51118153   서울
# 10  202311  49451765   서울
# 11  202312  52547645   서울

# %%
month_visitor_2020 = pd.concat(objs=[IC_month_visitor_2020,BS_month_visitor_2020,SU_month_visitor_2020,JJ_month_visitor_2020,GW_month_visitor_2020])
month_visitor_2020
# Out:
#       기준년월     방문자_수 지역구분
# 0   202301  14321833   인천
# 1   202302  13187354   인천
# 2   202303  15620369   인천
# 3   202304  13830096   인천
# 4   202305  15906026   인천
# 5   202306  14338822   인천
# 6   202307  15492589   인천
# 7   202308  15449316   인천
# 8   202309  16422889   인천
# 9   202310  16131144   인천
# 10  202311  14341875   인천
# 11  202312  15642889   인천
# 0   202301  13180063   부산
# 1   202302  11238505   부산
# 2   202303  13159913   부산
# 3   202304  11489345   부산
# 4   202305  12455221   부산
# 5   202306  11702524   부산
# 6   202307  12825366   부산
# 7   202308  13322368   부산
# 8   202309  13666837   부산
# 9   202310  12641711   부산
# 10  202311  11626722   부산
# 11  202312  12946350   부산
# 0   202301  47255715   서울
# 1   202302  47090565   서울
# 2   202303  54980858   서울
# 3   202304  45025765   서울
# 4   202305  49506461   서울
# 5   202306  47768488   서울
# 6   202307  50292484   서울
# 7   202308  49277340   서울
# 8   202309  51928425   서울
# 9   202310  51118153   서울
# ...

# %%
month_visitor_2020.to_csv('month_visitor_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## 인기관광지

# %%
import pandas as pd
GW_attraction_place_2020 = pd.read_csv("강원_인기관광지_외지인.csv", encoding='euc-kr')
GW_attraction_place_2020['지역구분'] = "강원"
IC_attraction_place_2020 = pd.read_csv("인천_인기관광지_외지인.csv", encoding='euc-kr')
IC_attraction_place_2020['지역구분'] = "인천"
JJ_attraction_place_2020 = pd.read_csv("제주_인기관광지_외지인.csv", encoding='euc-kr')
JJ_attraction_place_2020['지역구분'] = "제주"
BS_attraction_place_2020 = pd.read_csv("부산_인기관광지_외지인.csv", encoding='euc-kr')
BS_attraction_place_2020['지역구분'] = "부산"
SU_attraction_place_2020 = pd.read_csv("서울_인기관광지_외지인.csv", encoding='euc-kr')
SU_attraction_place_2020['지역구분'] = "서울"
SU_attraction_place_2020
# Out:
#      순위                        관광지명                  주소    분류  외지인 검색 수 지역구분
# 0     1                   김포국제공항국내선    서울 강서구 하늘길 111-0  교통시설   1683037   서울
# 1     2                       더현대서울  서울 영등포구 여의대로 108-0   백화점    880472   서울
# 2     3                         서울역   서울 용산구 한강대로 405-0  교통시설    872674   서울
# 3     4                      SRT수서역    서울 강남구 밤고개로 99-0  교통시설    739104   서울
# 4     5                         코엑스   서울 강남구 영동대로 513-0  전시시설    616007   서울
# ..  ...                         ...                 ...   ...       ...  ...
# 95   96                 반얀트리클럽앤스파서울     서울 중구 장충단로 60-0    호텔     75650   서울
# 96   97                       블루스퀘어   서울 용산구 이태원로 294-0  공연시설     74537   서울
# 97   98                   뉴코아아울렛강남점     서울 서초구 잠원로 69-0  대형마트     73673   서울
# 98   99  소피텔 앰배서더 서울 호텔 앤 서비스드 레지던스    서울 송파구 잠실로 209-0    호텔     72701   서울
# 99  100                   롯데월드아쿠아리움   서울 송파구 올림픽로 300-0  테마공원     72194   서울
#
# [100 rows x 6 columns]

# %%
import pandas as pd
GW_restaurant_place_2020 = pd.read_csv("강원_지역_맛집_외지인.csv", encoding='euc-kr')
GW_restaurant_place_2020['지역구분'] = "강원"
IC_restaurant_place_2020 = pd.read_csv("인천_지역_맛집_외지인.csv", encoding='euc-kr')
IC_restaurant_place_2020['지역구분'] = "인천"
JJ_restaurant_place_2020 = pd.read_csv("제주_지역_맛집_외지인.csv", encoding='euc-kr')
JJ_restaurant_place_2020['지역구분'] = "제주"
BS_restaurant_place_2020 = pd.read_csv("부산_지역_맛집_외지인.csv", encoding='euc-kr')
BS_restaurant_place_2020['지역구분'] = "부산"
SU_restaurant_place_2020 = pd.read_csv("서울_지역_맛집_외지인.csv", encoding='euc-kr')
SU_restaurant_place_2020['지역구분'] = "서울"
SU_restaurant_place_2020
# Out:
#      순위            업소명                   주소     분류  외지인 검색 수 지역구분
# 0     1      스타벅스더북한산점    서울 은평구 대서문길 24-11  카페/찻집     93299   서울
# 1     2     소문난성수감자탕본관     서울 성동구 연무장길 45-0     한식     45563   서울
# 2     3          우래옥본점     서울 중구 창경궁로 62-29     한식     43836   서울
# 3     4           또순이네  서울 영등포구 선유로47길 16-0     한식     42823   서울
# 4     5         이디야커피랩     서울 강남구 논현로 636-0  카페/찻집     40341   서울
# ..  ...            ...                  ...    ...       ...  ...
# 95   96         유천냉면본점   서울 송파구 강동대로3길 22-0     한식     13845   서울
# 96   97      버드나무집서초본점     서울 서초구 효령로 434-0     한식     13834   서울
# 97   98  진옥화할매원조닭한마리본점   서울 종로구 종로40가길 18-0     한식     13832   서울
# 98   99        한소반청계산점    서울 서초구 청계산로 249-0   전문음식     13822   서울
# 99  100          소호정본점      서울 서초구 논현로 27-0     한식     13705   서울
#
# [100 rows x 6 columns]

# %%
# Out:
#      순위          관광지명                 주소     분류  현지인 검색 수 지역구분
# 0     1   포레스트아웃팅스송도점   인천 연수구 청량로 145-0  카페/찻집     23158   인천
# 1     2  맥도날드송도GS DT점  인천 연수구 하모니로 128-0   간이음식     22505   인천
# 2     3   스타벅스인천청라DT점   인천 서구 국제대로 237-0  카페/찻집     21869   인천
# 3     4     맥도날드연희DT점    인천 서구 서곶로 265-0   간이음식     20879   인천
# 4     5   맥도날드인천청라DT점      인천 서구 원창로 8-0   간이음식     18065   인천
# ..  ...           ...                ...    ...       ...  ...
# 95   96        88생선구이  강원 속초시 중앙부두길 71-0     한식      2408   강원
# 96   97       쿠우쿠우춘천점    강원 춘천시 지석로 80-0   전문음식      2402   강원
# 97   98        학산시골밥상   강원 강릉시 범일로 131-0     한식      2394   강원
# 98   99    KFC원주단계DT점  강원 원주시 북원로 2266-0   간이음식      2365   강원
# 99  100         베이커리궁   강원 원주시 행구로 307-0   간이음식      2356   강원
#
# [500 rows x 6 columns]

# %%
restaurant_place_2020 = pd.concat(objs=[IC_restaurant_place_2020,BS_restaurant_place_2020,SU_restaurant_place_2020,JJ_restaurant_place_2020,GW_restaurant_place_2020])
restaurant_place_2020 = restaurant_place_2020.rename(columns={'업소명': '관광지명'})
restaurant_place_2020['분류'].unique()
# Out:
# array(['카페/찻집', '음식점기타', '외국식', '간이음식', '전문음식', '한식'], dtype=object)

# %%
attraction_place_2020 = pd.concat(objs=[IC_attraction_place_2020,BS_attraction_place_2020,SU_attraction_place_2020,JJ_attraction_place_2020,GW_attraction_place_2020])
attraction_place_2020
# Out:
#      순위           관광지명                      주소           분류  외지인 검색 수 지역구분
# 0     1  인천국제공항제1여객터미널         인천 중구 공항로 272-0         교통시설   2933860   인천
# 1     2  인천국제공항제2여객터미널     인천 중구 제2터미널대로 446-0         교통시설   1414181   인천
# 2     3   현대프리미엄아울렛송도점     인천 연수구 송도국제대로 123-0          쇼핑몰    556465   인천
# 3     4       롯데백화점인천점        인천 미추홀구 연남로 35-0          백화점    332094   인천
# 4     5        인천종합터미널        인천 미추홀구 연남로 35-0         교통시설    232112   인천
# ..  ...            ...                     ...          ...       ...  ...
# 95   96      춘천시외버스터미널       강원 춘천시 경춘로 2341-0         교통시설     36134   강원
# 96   97          씨마크호텔     강원 강릉시 해안로406번길 2-0           호텔     35622   강원
# 97   98            묵호항                  강원 동해시  자연경관(하천/해양)     35522   강원
# 98   99         설악워터피아  강원 속초시 미시령로2983번길 88-0         테마공원     35294   강원
# 99  100    용평리조트그린피아콘도       강원 평창군 올림픽로 715-0        콘도미니엄     34630   강원
#
# [500 rows x 6 columns]

# %%
attraction_place_2020 = pd.concat(objs=[attraction_place_2020,restaurant_place_2020])
attraction_place_2020
# Out:
#      순위           관광지명                   주소     분류  외지인 검색 수 지역구분
# 0     1  인천국제공항제1여객터미널      인천 중구 공항로 272-0   교통시설   2933860   인천
# 1     2  인천국제공항제2여객터미널  인천 중구 제2터미널대로 446-0   교통시설   1414181   인천
# 2     3   현대프리미엄아울렛송도점  인천 연수구 송도국제대로 123-0    쇼핑몰    556465   인천
# 3     4       롯데백화점인천점     인천 미추홀구 연남로 35-0    백화점    332094   인천
# 4     5        인천종합터미널     인천 미추홀구 연남로 35-0   교통시설    232112   인천
# ..  ...            ...                  ...    ...       ...  ...
# 95   96        호원가든닭갈비   강원 춘천시 북한강변길 346-0   전문음식     11495   강원
# 96   97          어나더블루   강원 속초시 장사항해안길 61-0  카페/찻집     11426   강원
# 97   98            인필드     강원 춘천시 가락재로 40-0  카페/찻집     11348   강원
# 98   99        강릉빵다방본점   강원 강릉시 남강초교1길 24-0   간이음식     11336   강원
# 99  100            신다신   강원 속초시 아바이마을길 22-0     한식     11272   강원
#
# [1500 rows x 6 columns]

# %%
attraction_place_2020.to_csv('attraction_place_2020.csv',index=False,encoding='utf-8')

# %% [markdown]
# ## 지역별 병합

# %%
import pandas as pd

# %%
import pandas as pd
consume_transition_2020_1 = pd.read_csv("강원_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_1['지역구분'] = "강원"
consume_transition_2020_2 = pd.read_csv("경기_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_2['지역구분'] = "경기"
consume_transition_2020_3 = pd.read_csv("경남_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_3['지역구분'] = "경남"
consume_transition_2020_4 = pd.read_csv("경북_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_4['지역구분'] = "경북"
consume_transition_2020_5 = pd.read_csv("광주_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_5['지역구분'] = "광주"
consume_transition_2020_6 = pd.read_csv("대구_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_6['지역구분'] = "대구"
consume_transition_2020_7 = pd.read_csv("대전_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_7['지역구분'] = "대전"
consume_transition_2020_8 = pd.read_csv("부산_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_8['지역구분'] = "부산"
consume_transition_2020_9 = pd.read_csv("서울_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_9['지역구분'] = "서울"
consume_transition_2020_10 = pd.read_csv("세종_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_10['지역구분'] = "세종"
consume_transition_2020_11 = pd.read_csv("울산_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_11['지역구분'] = "울산"
consume_transition_2020_12 = pd.read_csv("인천_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_12['지역구분'] = "인천"
consume_transition_2020_13 = pd.read_csv("전남_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_13['지역구분'] = "전남"
consume_transition_2020_14 = pd.read_csv("전북_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_14['지역구분'] = "전북"
consume_transition_2020_15 = pd.read_csv("제주_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_15['지역구분'] = "제주"
consume_transition_2020_16 = pd.read_csv("충남_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_16['지역구분'] = "충남"
consume_transition_2020_17 = pd.read_csv("충북_2020_관광소비 추이_내국인.csv", encoding='euc-kr')
consume_transition_2020_17['지역구분'] = "충북"
consume_transition_2020 = pd.concat(objs=[consume_transition_2020_1,consume_transition_2020_2,consume_transition_2020_3,consume_transition_2020_4,consume_transition_2020_5,consume_transition_2020_6,consume_transition_2020_7,consume_transition_2020_8,consume_transition_2020_9,consume_transition_2020_10,consume_transition_2020_11,consume_transition_2020_12,consume_transition_2020_13,consume_transition_2020_14,consume_transition_2020_15,consume_transition_2020_16,consume_transition_2020_17])
consume_transition_2020
consume_transition_2020.to_csv('consume_transition_2020.csv',index=False,encoding='utf-8')

# %%
consume_2020_1 = pd.read_csv("강원_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_1['지역구분'] = "강원"
consume_2020_2 = pd.read_csv("경기_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_2['지역구분'] = "경기"
consume_2020_3 = pd.read_csv("경남_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_3['지역구분'] = "경남"
consume_2020_4 = pd.read_csv("경북_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_4['지역구분'] = "경북"
consume_2020_5 = pd.read_csv("광주_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_5['지역구분'] = "광주"
consume_2020_6 = pd.read_csv("대구_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_6['지역구분'] = "대구"
consume_2020_7 = pd.read_csv("대전_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_7['지역구분'] = "대전"
consume_2020_8 = pd.read_csv("부산_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_8['지역구분'] = "부산"
consume_2020_9 = pd.read_csv("서울_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_9['지역구분'] = "서울"
consume_2020_10 = pd.read_csv("세종_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_10['지역구분'] = "세종"
consume_2020_11 = pd.read_csv("울산_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_11['지역구분'] = "울산"
consume_2020_12 = pd.read_csv("인천_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_12['지역구분'] = "인천"
consume_2020_13 = pd.read_csv("전남_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_13['지역구분'] = "전남"
consume_2020_14 = pd.read_csv("전북_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_14['지역구분'] = "전북"
consume_2020_15 = pd.read_csv("제주_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_15['지역구분'] = "제주"
consume_2020_16 = pd.read_csv("충남_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_16['지역구분'] = "충남"
consume_2020_17 = pd.read_csv("충북_2020_관광소비_내국인.csv", encoding='euc-kr')
consume_2020_17['지역구분'] = "충북"
consume_2020 = pd.concat(objs=[consume_2020_1,consume_2020_2,consume_2020_3,consume_2020_4,consume_2020_5,consume_2020_6,consume_2020_7,consume_2020_8,consume_2020_9,consume_2020_10,consume_2020_11,consume_2020_12,consume_2020_13,consume_2020_14,consume_2020_15,consume_2020_16,consume_2020_17])
consume_2020
consume_2020.to_csv('consume_2020.csv',index=False,encoding='utf-8')

# %%
concept_search_2020_1 = pd.read_csv("강원_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_1['지역구분'] = "강원"
concept_search_2020_2 = pd.read_csv("경기_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_2['지역구분'] = "경기"
concept_search_2020_3 = pd.read_csv("경남_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_3['지역구분'] = "경남"
concept_search_2020_4 = pd.read_csv("경북_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_4['지역구분'] = "경북"
concept_search_2020_5 = pd.read_csv("광주_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_5['지역구분'] = "광주"
concept_search_2020_6 = pd.read_csv("대구_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_6['지역구분'] = "대구"
concept_search_2020_7 = pd.read_csv("대전_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_7['지역구분'] = "대전"
concept_search_2020_8 = pd.read_csv("부산_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_8['지역구분'] = "부산"
concept_search_2020_9 = pd.read_csv("서울_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_9['지역구분'] = "서울"
concept_search_2020_10 = pd.read_csv("세종_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_10['지역구분'] = "세종"
concept_search_2020_11 = pd.read_csv("울산_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_11['지역구분'] = "울산"
concept_search_2020_12 = pd.read_csv("인천_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_12['지역구분'] = "인천"
concept_search_2020_13 = pd.read_csv("전남_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_13['지역구분'] = "전남"
concept_search_2020_14 = pd.read_csv("전북_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_14['지역구분'] = "전북"
concept_search_2020_15 = pd.read_csv("제주_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_15['지역구분'] = "제주"
concept_search_2020_16 = pd.read_csv("충남_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_16['지역구분'] = "충남"
concept_search_2020_17 = pd.read_csv("충북_2020_목적지 유형별 검색량.csv", encoding='euc-kr')
concept_search_2020_17['지역구분'] = "충북"
concept_search_2020 = pd.concat(objs=[concept_search_2020_1,concept_search_2020_2,concept_search_2020_3,concept_search_2020_4,concept_search_2020_5,concept_search_2020_6,concept_search_2020_7,concept_search_2020_8,concept_search_2020_9,concept_search_2020_10,concept_search_2020_11,concept_search_2020_12,concept_search_2020_13,concept_search_2020_14,concept_search_2020_15,concept_search_2020_16,concept_search_2020_17])
concept_search_2020
concept_search_2020.to_csv('concept_search_2020.csv',index=False,encoding='utf-8')

# %%
trend_search_2020_1 = pd.read_csv("강원_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_1['지역구분'] = "강원"
trend_search_2020_2 = pd.read_csv("경기_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_2['지역구분'] = "경기"
trend_search_2020_3 = pd.read_csv("경남_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_3['지역구분'] = "경남"
trend_search_2020_4 = pd.read_csv("경북_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_4['지역구분'] = "경북"
trend_search_2020_5 = pd.read_csv("광주_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_5['지역구분'] = "광주"
trend_search_2020_6 = pd.read_csv("대구_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_6['지역구분'] = "대구"
trend_search_2020_7 = pd.read_csv("대전_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_7['지역구분'] = "대전"
trend_search_2020_8 = pd.read_csv("부산_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_8['지역구분'] = "부산"
trend_search_2020_9 = pd.read_csv("서울_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_9['지역구분'] = "서울"
trend_search_2020_10 = pd.read_csv("세종_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_10['지역구분'] = "세종"
trend_search_2020_11 = pd.read_csv("울산_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_11['지역구분'] = "울산"
trend_search_2020_12 = pd.read_csv("인천_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_12['지역구분'] = "인천"
trend_search_2020_13 = pd.read_csv("전남_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_13['지역구분'] = "전남"
trend_search_2020_14 = pd.read_csv("전북_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_14['지역구분'] = "전북"
trend_search_2020_15 = pd.read_csv("제주_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_15['지역구분'] = "제주"
trend_search_2020_16 = pd.read_csv("충남_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_16['지역구분'] = "충남"
trend_search_2020_17 = pd.read_csv("충북_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
trend_search_2020_17['지역구분'] = "충북"
trend_search_2020 = pd.concat(objs=[trend_search_2020_1,trend_search_2020_2,trend_search_2020_3,trend_search_2020_4,trend_search_2020_5,trend_search_2020_6,trend_search_2020_7,trend_search_2020_8,trend_search_2020_9,trend_search_2020_10,trend_search_2020_11,trend_search_2020_12,trend_search_2020_13,trend_search_2020_14,trend_search_2020_15,trend_search_2020_16,trend_search_2020_17])
trend_search_2020
trend_search_2020.to_csv('trend_search_2020.csv',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 trend_search_2020_1 = pd.read_csv("강원_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
#       2 trend_search_2020_1['지역구분'] = "강원"
#       3 trend_search_2020_2 = pd.read_csv("경기_2020_여행유형_트렌드 언급량.csv", encoding='euc-kr')
#
# ...

# %%
attraction_2020_1 = pd.read_csv("강원_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_1['지역구분'] = "강원"
attraction_2020_2 = pd.read_csv("경기_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_2['지역구분'] = "경기"
attraction_2020_3 = pd.read_csv("경남_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_3['지역구분'] = "경남"
attraction_2020_4 = pd.read_csv("경북_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_4['지역구분'] = "경북"
attraction_2020_5 = pd.read_csv("광주_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_5['지역구분'] = "광주"
attraction_2020_6 = pd.read_csv("대구_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_6['지역구분'] = "대구"
attraction_2020_7 = pd.read_csv("대전_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_7['지역구분'] = "대전"
attraction_2020_8 = pd.read_csv("부산_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_8['지역구분'] = "부산"
attraction_2020_9 = pd.read_csv("서울_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_9['지역구분'] = "서울"
attraction_2020_10 = pd.read_csv("세종_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_10['지역구분'] = "세종"
attraction_2020_11 = pd.read_csv("울산_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_11['지역구분'] = "울산"
attraction_2020_12 = pd.read_csv("인천_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_12['지역구분'] = "인천"
attraction_2020_13 = pd.read_csv("전남_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_13['지역구분'] = "전남"
attraction_2020_14 = pd.read_csv("전북_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_14['지역구분'] = "전북"
attraction_2020_15 = pd.read_csv("제주_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_15['지역구분'] = "제주"
attraction_2020_16 = pd.read_csv("충남_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_16['지역구분'] = "충남"
attraction_2020_17 = pd.read_csv("충북_2020_인기관광지_외지인.csv", encoding='euc-kr')
attraction_2020_17['지역구분'] = "충북"
attraction_2020 = pd.concat(objs=[attraction_2020_1,attraction_2020_2,attraction_2020_3,attraction_2020_4,attraction_2020_5,attraction_2020_6,attraction_2020_7,attraction_2020_8,attraction_2020_9,attraction_2020_10,attraction_2020_11,attraction_2020_12,attraction_2020_13,attraction_2020_14,attraction_2020_15,attraction_2020_16,attraction_2020_17])
attraction_2020

# %%
retaurant_2020_1 = pd.read_csv("강원_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_1['지역구분'] = "강원"
retaurant_2020_2 = pd.read_csv("경기_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_2['지역구분'] = "경기"
retaurant_2020_3 = pd.read_csv("경남_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_3['지역구분'] = "경남"
retaurant_2020_4 = pd.read_csv("경북_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_4['지역구분'] = "경북"
retaurant_2020_5 = pd.read_csv("광주_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_5['지역구분'] = "광주"
retaurant_2020_6 = pd.read_csv("대구_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_6['지역구분'] = "대구"
retaurant_2020_7 = pd.read_csv("대전_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_7['지역구분'] = "대전"
retaurant_2020_8 = pd.read_csv("부산_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_8['지역구분'] = "부산"
retaurant_2020_9 = pd.read_csv("서울_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_9['지역구분'] = "서울"
retaurant_2020_10 = pd.read_csv("세종_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_10['지역구분'] = "세종"
retaurant_2020_11 = pd.read_csv("울산_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_11['지역구분'] = "울산"
retaurant_2020_12 = pd.read_csv("인천_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_12['지역구분'] = "인천"
retaurant_2020_13 = pd.read_csv("전남_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_13['지역구분'] = "전남"
retaurant_2020_14 = pd.read_csv("전북_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_14['지역구분'] = "전북"
retaurant_2020_15 = pd.read_csv("제주_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_15['지역구분'] = "제주"
retaurant_2020_16 = pd.read_csv("충남_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_16['지역구분'] = "충남"
retaurant_2020_17 = pd.read_csv("충북_2020_지역_맛집_외지인.csv", encoding='euc-kr')
retaurant_2020_17['지역구분'] = "충북"
retaurant_2020 = pd.concat(objs=[retaurant_2020_1,retaurant_2020_2,retaurant_2020_3,retaurant_2020_4,retaurant_2020_5,retaurant_2020_6,retaurant_2020_7,retaurant_2020_8,retaurant_2020_9,retaurant_2020_10,retaurant_2020_11,retaurant_2020_12,retaurant_2020_13,retaurant_2020_14,retaurant_2020_15,retaurant_2020_16,retaurant_2020_17])
retaurant_2020
retaurant_2020 = retaurant_2020.rename(columns={'업소명': '관광지명'})
retaurant_2020['분류'].unique()
attraction_2020 = pd.concat(objs=[attraction_2020,retaurant_2020])
attraction_2020.to_csv('attraction_2020.csv',index=False,encoding='utf-8')
# Out:
# array(['한식', '전문음식', '카페/찻집', '간이음식', '음식점기타', '외국식'], dtype=object)
